# %%
# !pip freeze
# Out:
# absl-py==0.9.0
# alabaster==0.7.12
# anaconda-client==1.7.2
# anaconda-navigator==1.9.6
# anaconda-project==0.8.2
# appdirs==1.4.3
# appnope==0.1.0
# appscript==1.0.1
# asn1crypto==0.24.0
# astor==0.8.1
# astroid==2.1.0
# astropy==4.0
# atomicwrites==1.2.1
# attrs==18.2.0
# autoencoder==0.0.7
# Automat==0.7.0
# autopep8==1.4.3
# Babel==2.6.0
# backcall==0.1.0
# backports.os==0.1.1
# backports.shutil-get-terminal-size==1.0.0
# beautifulsoup4==4.6.3
# bitarray==0.8.3
# bkcharts==0.2
# blaze==0.11.3
# bleach==3.0.2
# blis==0.4.1
# bokeh==1.4.0
# boto==2.49.0
# Bottleneck==1.3.2
# bs4==0.0.1
# cachetools==4.0.0
# catalogue==1.0.0
# category-encoders==2.0.0
# certifi==2019.11.28
# cffi==1.11.5
# chardet==3.0.4
# chart-studio==1.0.0
# Click==7.0
# click-plugins==1.0.4
# cligj==0.5.0
# cloudpickle==0.6.1
# clyent==1.2.2
# colorama==0.4.0
# colorcet==2.0.2
# colorlover==0.3.0
# combo==0.1.0
# conda==4.8.2
# conda-build==3.17.0
# conda-package-handling==1.6.0
# confuse==1.0.0
# constantly==15.1.0
# contextlib2==0.5.5
# cryptography==2.5
# cufflinks==0.17.0
# cycler==0.10.0
# cymem==2.0.3
# Cython==0.29
# cytoolz==0.9.0.1
# dask==1.0.0
# datashape==0.5.4
# decorator==4.3.0
# defusedxml==0.5.0
# descartes==1.1.0
# distributed==1.25.0
# docutils==0.14
# en-core-web-sm==2.2.5
# entrypoints==0.2.3
# et-xmlfile==1.0.1
# example-pkg-YOUR-USERNAME-HERE==0.0.1
# fastcache==1.0.2
# filelock==3.0.10
# Fiona==1.8.4
# Flask==1.0.2
# Flask-Cors==3.0.7
# future==0.17.1
# gast==0.3.3
# GDAL==2.3.3
# geopandas==0.3.0
# gevent==1.3.7
# glob2==0.6
# gmpy2==2.0.8
# google-auth==1.11.2
# google-auth-oauthlib==0.4.1
# google-pasta==0.1.8
# greenlet==0.4.15
# grpcio==1.27.2
# h5py==2.10.0
# hdbscan==0.8.24
# heapdict==1.0.0
# html5lib==1.0.1
# htmlmin==0.1.12
# hyperlink==18.0.0
# hypothesis==4.39.0
# idna==2.7
# imageio==2.8.0
# imagesize==1.1.0
# imbalanced-learn==0.5.0
# imblearn==0.0
# importlib-metadata==1.4.0
# incremental==17.5.0
# inflection==0.3.1
# ipykernel==5.1.0
# ipython==7.2.0
# ipython-cypher==0.2.6
# ipython-genutils==0.2.0
# ipywidgets==7.4.2
# isort==4.3.4
# itsdangerous==1.1.0
# jdcal==1.4
# jedi==0.13.3
# Jinja2==2.10
# joblib==0.14.1
# jsonschema==2.6.0
# jupyter==1.0.0
# jupyter-client==5.3.4
# jupyter-console==6.0.0
# jupyter-contrib-core==0.3.3
# jupyter-contrib-nbextensions==0.5.1
# jupyter-core==4.6.2
# jupyter-highlight-selected-word==0.2.0
# jupyter-latex-envs==1.4.6
# jupyter-nbextensions-configurator==0.4.1
# jupyterlab==0.35.3
# jupyterlab-launcher==0.13.1
# jupyterlab-server==0.2.0
# Keras==2.3.1
# Keras-Applications==1.0.8
# Keras-Preprocessing==1.1.0
# keyring==16.1.1
# kiwisolver==1.0.1
# lazy-object-proxy==1.3.1
# libarchive-c==2.8
# lief==0.9.0
# lifenoteasy==0.0.1
# lightgbm==2.3.1
# llvmlite==0.31.0
# locket==0.2.0
# lxml==4.2.5
# mapclassify==2.0.1
# Markdown==3.2.1
# MarkupSafe==1.1.0
# matplotlib==3.1.1
# mccabe==0.6.1
# mglearn==0.1.7
# missingno==0.4.2
# mistune==0.8.4
# mkl-fft==1.0.10
# mkl-random==1.0.2
# mlxtend==0.17.1
# mock==3.0.5
# more-itertools==4.3.0
# mpmath==1.0.0
# msca==0.0.1
# msgpack==0.5.6
# multipledispatch==0.6.0
# munch==2.3.2
# murmurhash==1.0.2
# navigator-updater==0.2.1
# nbconvert==5.4.0
# nbformat==4.4.0
# ndg-httpsclient==0.5.1
# neo4jrestclient==2.1.1
# neobolt==1.7.15
# neotime==1.7.4
# networkx==2.2
# nltk==3.3
# nose==1.3.7
# notebook==5.7.2
# numba==0.48.0
# numexpr==2.7.0
# numpy==1.16.2
# numpydoc==0.8.0
# oauthlib==3.1.0
# odo==0.5.1
# olefile==0.46
# openpyxl==2.5.11
# packaging==18.0
# pandas==1.0.1
# pandas-compat==0.1.1
# pandas-profiling==2.4.0
# pandocfilters==1.4.2
# param==1.9.3
# parso==0.3.1
# partd==0.3.9
# path.py==11.5.0
# pathlib-mate==0.0.15
# pathlib2==2.3.2
# patsy==0.5.1
# pep8==1.7.1
# pexpect==4.6.0
# phik==0.9.9
# pickleshare==0.7.5
# Pillow==5.3.0
# pkginfo==1.4.2
# plac==1.1.3
# plotly==4.1.1
# pluggy==0.13.1
# ply==3.11
# preshed==3.0.2
# prettytable==0.7.2
# prometheus-client==0.4.2
# prompt-toolkit==2.0.7
# protobuf==3.11.3
# psutil==5.4.8
# psycopg2==2.7.6.1
# ptyprocess==0.6.0
# py==1.7.0
# py2neo==4.3.0
# pyasn1==0.4.4
# pyasn1-modules==0.2.2
# pycodestyle==2.4.0
# pycosat==0.6.3
# pycparser==2.19
# pycrypto==2.6.1
# pyct==0.4.6
# pycurl==7.43.0.2
# pydocstyle==3.0.0
# pyflakes==2.0.0
# Pygments==2.3.1
# pylint==2.2.2
# pymongo==3.9.0
# PyMySQL==0.9.3
# pyod==0.7.7.1
# pyodbc==4.0.24
# pyOpenSSL==18.0.0
# pyparsing==2.3.0
# pyproj==1.9.6
# pyrsistent==0.15.7
# pyshp==1.2.10
# PySocks==1.6.8
# pytest==5.3.5
# pytest-arraydiff==0.3
# pytest-astropy==0.7.0
# pytest-astropy-header==0.1.2
# pytest-doctestplus==0.4.0
# pytest-openfiles==0.3.1
# pytest-pylint==0.15.0
# pytest-remotedata==0.3.1
# python-dateutil==2.7.5
# python-jsonrpc-server==0.1.2
# python-language-server==0.26.1
# pytz==2018.7
# PyWavelets==1.1.1
# PyYAML==3.13
# pyzmq==17.1.2
# QtAwesome==0.5.3
# qtconsole==4.4.2
# QtPy==1.5.2
# Quandl==3.4.8
# requests==2.23.0
# requests-oauthlib==1.3.0
# retrying==1.3.3
# rope==0.11.0
# rsa==4.0
# Rtree==0.8.3
# ruamel-yaml==0.15.46
# scattertext==0.0.2.56
# scikit-image==0.15.0
# scikit-learn==0.22.1
# scipy==1.4.1
# seaborn==0.9.0
# Send2Trash==1.5.0
# service-identity==17.0.0
# Shapely==1.6.4.post2
# simplegeneric==0.8.1
# singledispatch==3.4.0.3
# six==1.14.0
# sklearn==0.0
# snowballstemmer==1.2.1
# sortedcollections==1.0.1
# sortedcontainers==2.0.5
# soupsieve==1.9.4
# spacy==2.2.3
# Sphinx==1.8.2
# sphinxcontrib-websupport==1.1.0
# spyder==3.3.2
# spyder-kernels==0.3.0
# SQLAlchemy==1.2.14
# srsly==1.0.1
# statsmodels==0.9.0
# suod==0.0.3
# sympy==1.3
# tables==3.4.4
# tblib==1.3.2
# tensorboard==2.1.1
# tensorflow==1.13.2
# tensorflow-estimator==1.13.0
# termcolor==1.1.0
# terminado==0.8.1
# testpath==0.4.2
# textblob==0.15.3
# thinc==7.3.1
# toolz==0.9.0
# tornado==5.1.1
# tqdm==4.28.1
# traitlets==4.3.2
# Twisted==17.5.0
# typed-ast==1.1.0
# unicodecsv==0.14.1
# urllib3==1.23
# uszipcode==0.2.4
# wasabi==0.6.0
# wcwidth==0.1.7
# webencodings==0.5.1
# Werkzeug==0.14.1
# widgetsnbextension==3.4.2
# wordcloud==1.6.0
# wrapt==1.10.11
# wurlitzer==1.0.2
# xlrd==1.1.0
# XlsxWriter==1.1.2
# xlwings==0.14.1
# xlwt==1.2.0
# yapf==0.27.0
# zict==0.1.3
# zipcodes==1.1.0
# zipp==3.1.0
# zope.interface==4.6.0

# %%
# !which python
# Out:
# /anaconda3/bin/python

# %%
# !pip install lifenoteasy
# Out:
# Requirement already satisfied: lifenoteasy in /anaconda3/lib/python3.6/site-packages/lifenoteasy-0.0.1-py3.6.egg (0.0.1)

# %%
import example_pkg

# %%
dir(example_pkg)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'base']

# %%
example_pkg.base.hello()
# Out:
# 'Hello Jenny!'

# %%
import os
import glob
import re

# %%
class salad():

    def __init__(self):
        self.path = ''
        self.items = []
        self.numbes = []
        
    def write(self, path, salad, n_items):
        self.path = path
        print(self.path)
        
        assert len(salad) == len(n_items), "Length of items and numbers should be equal."
        os.makedirs(self.path, exist_ok=True)
        # should receive a path
        # should receive a list of salad items
        # should receive a list of number of salad items
        # should write a file with item_00.salad
        for k in range(len(salad)):
            print(salad[k], n_items[k])
            for j in range(n_items[k]):
                file_name = salad[k]+'{:0>2}'.format(j)+'.salad'
                print(os.path.join(self.path, file_name))
                f = open(os.path.join(self.path, file_name), 'w')
                f.close()

    # input path, [tomato, lettuce], [2,3]
    # xxx/tomato_00.salad
    # xxx/tomato_01.salad
    # xxx/lettuce_00.salad
    # xxx/lettuce_01.salad
    # xxx/lettuce_02.salad

    
    def read(self, path):
        # read the .salad files
        # return a dictionary with salad items and how many there are
        flist = glob.glob(os.path.join(path, '*.salad'))
        a = []
        for file in flist:
            pattern = r'(\w+)(\d\d).salad'
            a.append(re.findall(pattern, file))
            
        tmp = []
        for i in a:
            tmp.append(list(i[0]))

        keys = [i[0] for i in tmp]

        values = [i[1] for i in tmp]

        answer = {key: 0 for key in keys}

        for key in keys:
            answer[key]+=1
        
        return answer

# %%
import timeit
start_time = timeit.default_timer()
path = './mysalad'
salad_items = ['lettuce', 'tomato']
salad_numbers = [2,3]

mysalad = salad()

mysalad.write(path, salad_items, salad_numbers)
flist = mysalad.read(path)

elapsed = timeit.default_timer() - start_time
# Out:
# ./mysalad
# lettuce 2
# ./mysalad/lettuce00.salad
# ./mysalad/lettuce01.salad
# tomato 3
# ./mysalad/tomato00.salad
# ./mysalad/tomato01.salad
# ./mysalad/tomato02.salad

# %%
elapsed
# Out:
# 0.008140194026054814

# %%
f = open('final_salad.txt', 'w+')
f.write('Jenny Zhen')
f.write('It took {}s to execute salad'.format(elapsed))
for k in flist:
    f.write(str(k))
f.close()

# %%
class salad():

    def __init__(self):
        self.path = ''
        self.items = []
        self.numbes = []
        
    def write(self, path, salad, n_items):
        self.path = path
        print(self.path)
        
        assert len(salad) == len(n_items), "Length of items and numbers should be equal."
        # should receive a path
        # should receive a list of salad items
        # should receive a list of number of salad items
        # should write a file with item_00.salad
        for idx, item in enumerate(item):
            num_file = num[idx]
            for i in range(0, num_file):
                f = open(path+"item_0{}.txt".format(i), "w")
                f.write(item)
                f.close()

    # input path, [tomato, lettuce], [2,3]
    # xxx/tomato_00.salad
    # xxx/tomato_01.salad
    # xxx/lettuce_00.salad
    # xxx/lettuce_01.salad
    # xxx/lettuce_02.salad

    
    def read(files):
        # read the .salad files
        # return a dictionary with salad items and how many there are
        lst = []
        for file in files:
            f = open(file, 'r')
            lst.append(f)

        counts = dict()
        for i in lst:
            counts[i] = counts.get(i, 0) + 1
        return counts

# %%
dir(salad)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'read',
#  'write']
